# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score, KFold, StratifiedKFold
import scipy.stats as stats
import statsmodels.api as sm
import seaborn as sns
from sklearn.metrics import roc_curve, auc, RocCurveDisplay
from sklearn import metrics
from sklearn.tree import DecisionTreeRegressor

# %%
data = pd.read_csv("county_level_election.csv")

# %%
data.head(10)
# Out:
#       state  fipscode                county  population  hispanic  minority  \
# 0  Colorado      8117         Summit County       27239    15.173     4.918
# 1  Colorado      8037          Eagle County       53653    30.040     5.169
# 2     Idaho     16067       Minidoka County       19226    34.070     5.611
# 3  Colorado      8113     San Miguel County        7558    10.154     4.747
# 4      Utah     49051        Wasatch County       21600    13.244     4.125
# 5  Virginia     51685    Manassas Park city       12042    37.079    31.044
# 6   Georgia     13053  Chattahoochee County       14402    15.676    28.352
# 7  Colorado      8097         Pitkin County       16043     9.782     4.526
# 8      Utah     49007         Carbon County       19989    13.409     5.205
# 9  Colorado      8051       Gunnison County       15350     9.392     5.794
#
#    female  unemployed  income  nodegree  bachelor  inactivity  obesity  \
# 0  45.996         2.5   68352       5.4      48.1         8.1     13.1
# 1  47.231         3.1   76661      10.1      47.3         9.4     11.8
# 2  49.318         3.7   46332      24.1      11.8        18.3     34.2
# 3  46.808         3.7   59603       4.7      54.4        12.4     16.7
# 4  48.812         3.4   65207       9.5      34.4        13.9     23.0
# 5  48.894         4.2   73065      18.9      26.3        21.1     28.3
# 6  31.624         8.8   45933       7.0      31.5        24.5     27.3
# 7  47.850         3.8   73274       5.2      56.4         8.9     14.9
# 8  50.325         5.6   47340      13.0      13.0        25.2     26.6
# 9  46.020         2.9   48940       5.5      54.4        11.2     14.8
#
#    density  cancer  votergap   trump  clinton
# 0     46.0    46.2   -27.632  31.530   59.162
# 1     31.0    47.1   -19.897  36.058   55.955
# 2     80.0    61.8    54.148  71.135   16.987
# 3      5.7    62.6   -44.769  23.892   68.662
# 4    257.8    68.3    25.357  50.471   25.114
# 5   5633.1    69.8   -28.500  33.218   61.718
# 6     45.3    70.0    11.055  53.902   42.847
# 7     17.7    70.8   -45.413  24.280   69.693
# 8     96.7    71.3    44.186  66.044   21.858
# 9      4.7    79.6   -19.550  34.950   54.500

# %%
X = data.drop(columns=["votergap"])
y = data["votergap"]

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
data.hist(figsize=(14,10))
plt.tight_layout()
plt.show()

# %%
tree = DecisionTreeRegressor(random_state=42)
cross_
#tree.fit(Xtrain, ytrain)

#print("R² train:", tree.score(Xtrain, ytrain))
#print("R² test :", tree.score(Xtest, ytest))
